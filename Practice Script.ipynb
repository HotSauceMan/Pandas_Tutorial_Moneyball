# %%
import pandas as pd
import numpy as np

# %%
# Importing data

df = pd.read_csv("Pitching.csv")
df
# pd.read_table helps with reading data tables. 
# pd.read_excel helps with reading excel files.
# Out:
#        Unnamed: 0   playerID  yearID  stint teamID lgID   W   L   G  GS  ...  \
# 0               0  bechtge01    1871      1    PH1  NaN   1   2   3   3  ...
# 1               1  brainas01    1871      1    WS3  NaN  12  15  30  30  ...
# 2               2  fergubo01    1871      1    NY2  NaN   0   0   1   0  ...
# 3               3  fishech01    1871      1    RC1  NaN   4  16  24  24  ...
# 4               4  fleetfr01    1871      1    NY2  NaN   0   1   1   1  ...
# ...           ...        ...     ...    ...    ...  ...  ..  ..  ..  ..  ...
# 44134       44134  youngch03    2015      1    KCA   AL  11   6  34  18  ...
# 44135       44135  zieglbr01    2015      1    ARI   NL   0   3  66   0  ...
# 44136       44136  zimmejo02    2015      1    WAS   NL  13  10  33  33  ...
# 44137       44137   zitoba01    2015      1    OAK   AL   0   0   3   2  ...
# 44138       44138   zychto01    2015      1    SEA   AL   0   0  13   1  ...
#
# ...

# %%
# Exporting data

# df.to_csv("Pitching.csv")

# %%
# Creating random testing objects

# df2 = pd.DataFrame(np.random.rand(8,5))
#df2
# Out:
#           0         1         2         3         4
# 0  0.517780  0.758859  0.159377  0.466618  0.611957
# 1  0.909736  0.102716  0.101456  0.803902  0.191921
# 2  0.074467  0.160232  0.631393  0.464098  0.606588
# 3  0.029627  0.759655  0.654690  0.447631  0.980420
# 4  0.320270  0.794261  0.933811  0.519881  0.966772
# 5  0.542696  0.087193  0.458636  0.790005  0.473599
# 6  0.403244  0.432686  0.184379  0.896482  0.251296
# 7  0.531775  0.997371  0.827078  0.042278  0.628834

# %%
# Basic Data Description

# df.head(10)
# df.tail(10)
# df.shape()
# df.info()
# df.describe()
# Out:
#          Unnamed: 0        yearID        stint             W             L  \
# count  44139.000000  44139.000000  44139.00000  44139.000000  44139.000000
# mean   22069.000000   1967.786493      1.07925      4.748794      4.748771
# std    12741.976103     37.352599      0.28443      5.837989      5.007080
# min        0.000000   1871.000000      1.00000      0.000000      0.000000
# 25%    11034.500000   1940.000000      1.00000      0.000000      1.000000
# 50%    22069.000000   1977.000000      1.00000      2.000000      3.000000
# 75%    33103.500000   2000.000000      1.00000      7.000000      8.000000
# max    44138.000000   2015.000000      4.00000     59.000000     48.000000
#
#                   G            GS            CG          SHO            SV  \
# count  44139.000000  44139.000000  44139.000000  44139.00000  44139.000000
# mean      23.667142      9.552550      3.207979      0.45615      1.503976
# ...

# %%
# Selecting parts of dataset

# df["playerID"]
# df[["playerID", "yearID"]]
# df.iloc[0,:]
# df.iloc[:,1]
# Out:
# 0        bechtge01
# 1        brainas01
# 2        fergubo01
# 3        fishech01
# 4        fleetfr01
#            ...
# 44134    youngch03
# 44135    zieglbr01
# 44136    zimmejo02
# 44137     zitoba01
# 44138     zychto01
# Name: playerID, Length: 44139, dtype: object

# %%
# Dropping columns

# list = ["playerID", "yearID"]
# df.drop(list, axis = 1)
# Out:
#        Unnamed: 0  stint teamID lgID   W   L   G  GS  CG  SHO  ...  IBB   WP  \
# 0               0      1    PH1  NaN   1   2   3   3   2    0  ...  NaN  NaN
# 1               1      1    WS3  NaN  12  15  30  30  30    0  ...  NaN  NaN
# 2               2      1    NY2  NaN   0   0   1   0   0    0  ...  NaN  NaN
# 3               3      1    RC1  NaN   4  16  24  24  22    1  ...  NaN  NaN
# 4               4      1    NY2  NaN   0   1   1   1   1    0  ...  NaN  NaN
# ...           ...    ...    ...  ...  ..  ..  ..  ..  ..  ...  ...  ...  ...
# 44134       44134      1    KCA   AL  11   6  34  18   0    0  ...  0.0  5.0
# 44135       44135      1    ARI   NL   0   3  66   0   0    0  ...  3.0  2.0
# 44136       44136      1    WAS   NL  13  10  33  33   0    0  ...  3.0  2.0
# 44137       44137      1    OAK   AL   0   0   3   2   0    0  ...  0.0  0.0
# 44138       44138      1    SEA   AL   0   0  13   1   0    0  ...  0.0  1.0
#
# ...

# %%
## Dealing with null values

# df.dropna()
# df.dropna(axis = 1)
# df.fillna('Lakers')
# df.isnull()
# df.rename(columns={'yearID': 'bob'})
# Out:
#        Unnamed: 0   playerID   bob  stint teamID lgID   W   L   G  GS  ...  \
# 0               0  bechtge01  1871      1    PH1  NaN   1   2   3   3  ...
# 1               1  brainas01  1871      1    WS3  NaN  12  15  30  30  ...
# 2               2  fergubo01  1871      1    NY2  NaN   0   0   1   0  ...
# 3               3  fishech01  1871      1    RC1  NaN   4  16  24  24  ...
# 4               4  fleetfr01  1871      1    NY2  NaN   0   1   1   1  ...
# ...           ...        ...   ...    ...    ...  ...  ..  ..  ..  ..  ...
# 44134       44134  youngch03  2015      1    KCA   AL  11   6  34  18  ...
# 44135       44135  zieglbr01  2015      1    ARI   NL   0   3  66   0  ...
# 44136       44136  zimmejo02  2015      1    WAS   NL  13  10  33  33  ...
# 44137       44137   zitoba01  2015      1    OAK   AL   0   0   3   2  ...
# 44138       44138   zychto01  2015      1    SEA   AL   0   0  13   1  ...
#
#        IBB   WP  HBP  BK    BFP    GF    R   SH   SF  GIDP
# ...

# %%
# Applications
# df.apply(np.mean)
# df.apply(np.max, axis = 0)

# %%
# More summary statistics
# df.mean()
# df.corr()
# Out:
#             Unnamed: 0    yearID     stint         W         L         G  \
# Unnamed: 0    1.000000  0.971709  0.011474 -0.183947 -0.214528  0.157971
# yearID        0.971709  1.000000  0.009592 -0.187937 -0.219115  0.168402
# stint         0.011474  0.009592  1.000000 -0.106852 -0.110185 -0.126115
# W            -0.183947 -0.187937 -0.106852  1.000000  0.741651  0.501459
# L            -0.214528 -0.219115 -0.110185  0.741651  1.000000  0.477008
# G             0.157971  0.168402 -0.126115  0.501459  0.477008  1.000000
# GS           -0.179937 -0.184491 -0.102889  0.872609  0.862979  0.302259
# CG           -0.445534 -0.489405 -0.057891  0.764619  0.695796  0.258985
# SHO          -0.260499 -0.252871 -0.062587  0.695123  0.517730  0.232435
# SV            0.090248  0.104388 -0.041977  0.032943  0.028107  0.475041
# IPouts       -0.226552 -0.231298 -0.120022  0.934844  0.889601  0.536578
# H            -0.241881 -0.251056 -0.117814  0.891605  0.907801  0.505447
# ...

# %%
# More summary statistics
# df.mean()
# df.corr()
